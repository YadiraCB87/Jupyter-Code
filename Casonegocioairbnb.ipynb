# %%
## importar librerias

import pandas as pd
import numpy as np

# %%
## Exploracion y carga de datos

alojamientos=pd.read_csv(r"C:\Users\ViG\Desktop\DataSets\Airbnb_Milan.csv")
alojamientos.head()
# Out:
#    Unnamed: 0      id  host_id  host_location  host_response_time  \
# 0           1   73892   387110              1                   1
# 1           2   74169   268127              1                   1
# 2           3   77958   387110              1                   1
# 3           4   93025   499743              1                   1
# 4           5  132705   391011              1                   1
#
#    host_response_rate  host_is_superhost  host_total_listings_count  \
# 0                  57                  0                          3
# 1                  57                  0                          1
# 2                  57                  0                          3
# 3                  57                  0                          1
# 4                  57                  1                          2
#
#    host_has_profile_pic  host_identity_verified  ...  Iron  Host_greets_you  \
# 0                     1                       1  ...     1                0
# ...

# %%
alojamientos.tail()
# Out:
#       Unnamed: 0        id    host_id  host_location  host_response_time  \
# 9317        9318  35954783   56584596              1                   1
# 9318        9319  36023503  271013325              1                   1
# 9319        9320  36071908  271354203              1                   0
# 9320        9321  36305676  171239896              1                   1
# 9321        9322  36463651  174590119              1                   1
#
#       host_response_rate  host_is_superhost  host_total_listings_count  \
# 9317                  57                  0                          1
# 9318                  57                  0                          1
# 9319                  57                  0                          1
# 9320                  40                  0                          3
# 9321                  57                  0                         14
#
#       host_has_profile_pic  host_identity_verified  ...  Iron  \
# ...

# %%
## Mostrar 10 lineas sin order estipulado (aleatorio)

alojamientos.sample(10)
# Out:
#       Unnamed: 0        id    host_id  host_location  host_response_time  \
# 6494        6495  24256521  182907931              1                   1
# 3914        3915  35633177   96015621              1                   1
# 127          128   2598713    6569482              1                   1
# 749          750  17888824  122370408              1                   1
# 369          370   6668801   27693585              1                   1
# 5707        5708  34624052    4481040              1                   1
# 5830        5831   2443599    6311023              1                   0
# 8525        8526   3428012   11535264              1                   1
# 3727        3728  31647580  237271246              1                   1
# 8942        8943  23553451   99632151              1                   1
#
#       host_response_rate  host_is_superhost  host_total_listings_count  \
# 6494                  57                  1                          1
# ...

# %%
## Revision de valores nulos y sustitucion de estos
## Creacion de reporte de Missing values 

missing_values_count = alojamientos.isnull().sum()
missing_values_count
# Out:
# Unnamed: 0             0
# id                     0
# host_id                0
# host_location          0
# host_response_time     0
#                       ..
# Doorman                0
# Pets_allowed           0
# Smoking_allowed        0
# Suitable_for_events    0
# 24_hour_check_in       0
# Length: 61, dtype: int64

# %%
## En caso de haber valores nulos se aplicaria la siguiente funcion
## Resultado se muestra en porcentajes

total_cells = np.product(alojamientos.shape)
total_missing = missing_values_count.sum()

print("% de valores nulos : "+str(total_missing/total_cells*100))
# Out:
# % de valores nulos : 0.0

# %%
## Como eliminar registros con valores NA
## No siempre se recomeinda eliminar valores nulos (deben ser analzaidos las variables asociadas)

copia_datos=alojamientos
copia_datos.dropna()
# Out:
#       Unnamed: 0        id    host_id  host_location  host_response_time  \
# 0              1     73892     387110              1                   1
# 1              2     74169     268127              1                   1
# 2              3     77958     387110              1                   1
# 3              4     93025     499743              1                   1
# 4              5    132705     391011              1                   1
# ...          ...       ...        ...            ...                 ...
# 9317        9318  35954783   56584596              1                   1
# 9318        9319  36023503  271013325              1                   1
# 9319        9320  36071908  271354203              1                   0
# 9320        9321  36305676  171239896              1                   1
# 9321        9322  36463651  174590119              1                   1
#
#       host_response_rate  host_is_superhost  host_total_listings_count  \
# ...

# %%
## Eliminar la columna completa

columns_with_na_dropped = alojamientos.dropna(axis=1)

## verificacion de columnas restantes

columns_with_na_dropped.head()

print("columnas en el conjunto de datos original: %d /n" % alojamientos.shape[1])
print("columnas finales: %d" % columns_with_na_dropped.shape[1])
# Out:
# columnas en el conjunto de datos original: 61 /n
# columnas finales: 61

# %%
## Reemplzar valores nulos (valores fijos)

copia2=alojamientos
copia2.fillna(1)
# Out:
#       Unnamed: 0        id    host_id  host_location  host_response_time  \
# 0              1     73892     387110              1                   1
# 1              2     74169     268127              1                   1
# 2              3     77958     387110              1                   1
# 3              4     93025     499743              1                   1
# 4              5    132705     391011              1                   1
# ...          ...       ...        ...            ...                 ...
# 9317        9318  35954783   56584596              1                   1
# 9318        9319  36023503  271013325              1                   1
# 9319        9320  36071908  271354203              1                   0
# 9320        9321  36305676  171239896              1                   1
# 9321        9322  36463651  174590119              1                   1
#
#       host_response_rate  host_is_superhost  host_total_listings_count  \
# ...

# %%
## reemplazar con valores especificos las variables necesarias

copia3=alojamientos

valores={'bedroom':1,'bathrooms':1}
copia3.fillna(value=valores)
# Out:
#       Unnamed: 0        id    host_id  host_location  host_response_time  \
# 0              1     73892     387110              1                   1
# 1              2     74169     268127              1                   1
# 2              3     77958     387110              1                   1
# 3              4     93025     499743              1                   1
# 4              5    132705     391011              1                   1
# ...          ...       ...        ...            ...                 ...
# 9317        9318  35954783   56584596              1                   1
# 9318        9319  36023503  271013325              1                   1
# 9319        9320  36071908  271354203              1                   0
# 9320        9321  36305676  171239896              1                   1
# 9321        9322  36463651  174590119              1                   1
#
#       host_response_rate  host_is_superhost  host_total_listings_count  \
# ...

# %%
## Analisis correlacion entre variables 

import seaborn as sn
import matplotlib.pyplot as plt

## seleccionamos las variables a mostrar

variables=['daily_price','bedrooms','accommodates','host_is_superhost','host_identity_verified','bathrooms','security_deposit','minimum_nights','number_of_reviews','review_scores_rating']
           
           
## se crea la matriz de correlacion
corrMatrix = alojamientos[variables].corr()
           
           
##Se genera el grafico
plt.figure(figsize=(10,6))
sn.heatmap(corrMatrix, annot=True)
plt.show()

# %%
## Relacion entre huespedes y habitaciones

## grafico de dispercion

plt.figure(figsize=(15,5))
plt.scatter(alojamientos.accommodates,alojamientos.bedrooms)
plt.xlabel("Huespedes")
plt.ylabel("Habitaciones")
plt.title("Grafico de dispersion huespedes-habitaciones")
plt.show()

# %%
## Relacion entre bañosy habitaciones

plt.figure(figsize=(15,5))
plt.scatter(alojamientos.bathrooms,alojamientos.bedrooms)
plt.xlabel("Baños")
plt.ylabel("Habitaciones")
plt.title("Grafico de dispersion baños-habitaciones")
plt.show()

# %%
## Distribucion de las variables

plt.figure(figsize=(20,6))
plt.hist(alojamientos.daily_price,bins=30)
plt.xlabel("Precio diario")
plt.ylabel("#Alojamientos")
plt.title("Histograma de Precios")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
## Habitaciones por alojamientos

plt.figure(figsize=(20,6))
plt.boxplot(alojamientos.bedrooms)
plt.ylabel("Habitaciones")
plt.title("Boxplot: Cantidad de habitaciones")
plt.show()

# %%
## Distrubucion de varaibles por agrupacion

intervalos_habitaciones = range(min(alojamientos.bedrooms), max(alojamientos.bedrooms)+3)
plt.figure(figsize=(16,6))

cant_habitacion=alojamientos.groupby('bedrooms')['bedrooms'].count()

plt.bar(cant_habitacion.index,cant_habitacion.values,color="Yellow")
plt.title('Distribuxion de alojamientos por # de habitaciones')
plt.xlabel('Numero de habitaciones')
plt.ylabel('Frecuencia')
plt.xticks(intervalos_habitaciones)
plt.show()

# %%
## Ubicacion de los Alojamientos

import numpy as np
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

##Llamar dataset

paises=pd.read_excel(r"C:\Users\ViG\Desktop\Ubication.xlsx")
#paises.head()

## Crear diccionario de colores para cada zona registrada

colors = {'Serbia': 'Green', 'Monaco': 'Pink', 'Australia': 'Purple', 'Belgium': 'Blue', 'France': 'Orange', 'Germany': 'Green', 'Malaysia': 'Green', 'Netherlands': 'Black'}

##Mapear las ubicaciones  de cada alojamiento con el color respectivo
ubicacion_color=paises.host_location.map(colors)


# Utiliza el diccionario de colores junto con el argumento 'c'

##Creacion grafico
#plt.figure(figsize=(18,8))
#plt.scatter(paises.latitude,paises.longitude,color=ubicacion_color)
#plt.title("Ubicacion de los Alojamientos")
#plt.xlabel("Latitud")
#plt.ylabel("Longitud")
#plt.show()

# %%
## Agrupacion de datos de acuerdo a su Ubicacion

cant_ubicacion = paises.groupby('host_location')['host_location'].count()

top_10_ubicaciones = cant_ubicacion.nlargest(4)

##Crear las variables que contengan los valores del series creado
##ubicaciones=cant_ubicacion.index
##cantidad=cant_ubicacion.values
ubicaciones = top_10_ubicaciones.index
cantidad = top_10_ubicaciones.values

#creacion grafico
plt.figure(figsize=(18,8))
plt.bar(ubicaciones,cantidad, color=colors.values())
plt.xticks(ubicaciones)
plt.title("Ubicacion de los Alojamientos por ubicacion",size=15)
plt.xlabel("host_location", size=14)
plt.ylabel("#Alojamientos",size=14)
plt.show()

# %%
## Agrupacion datos segun su ubicacion

precio_alojamientos_ubicacion=paises.groupby('host_location')['price'].mean()

top_10_precios = precio_alojamientos_ubicacion.nlargest(5)
                                                                
##crear variables que contienen los valores del series creado
                                                                
localidades=top_10_precios.index
precios=top_10_precios.values
                                                                
##creacion grafico
plt.figure(figsize=(16,8))
plt.bar(localidades,precios, color=colors.values())
plt.xticks(localidades)
plt.title("Precio segun zona",size=20)
plt.xlabel("Ubicacion", size=18)
plt.ylabel("Precio",size=14)
plt.show()

# %%
## Graficos de barra siempre inician en 0

plt.figure(figsize=(30,6))

plt.subplot(132)
plt.scatter(localidades, precios)
plt.ylabel("Precio", size=15)
plt.title('Grafico de puntos precio',size=16)


plt.subplot(133)
plt.plot(localidades, precios,color='r')
plt.ylabel("Precio", size=15)
plt.title('Grafico de lineas precio',size=16)
plt.show()

# %%
plt.figure(figsize=(30,6))

plt.subplot(132)
plt.title('Precio diario de alojamientos con Outliers',size=16)
plt.boxplot(paises.price)
plt.ylabel("Precio Diario", size=14)



plt.subplot(133)
plt.title('Precio diario de alojamientos con Outliers',size=16)
plt.boxplot(paises.price,showfliers=False)
plt.ylabel("Precio Diario", size=14)
plt.show()

# %%
##Analisis variable superhost, calificacion de alojamiento superhost o no superhost 

import matplotlib.pyplot as plt

# %%
##calcular la cantidad de superhost y no superhost

superh=paises[paises.host_listings_count==1]
no_superh=paises[paises.host_listings_count==0]

print("Cantidad de SuperHost: "+str(superh.shape[0]))
print("Cantidad de No SuperHost: "+str(no_superh.shape[0]))
# Out:
# Cantidad de SuperHost: 6294
# Cantidad de No SuperHost: 0

# %%
cantidades=[superh.shape[0],no_superh.shape[0]]
etiquetas = ['SuperHost', 'No SuperHost']

## creacion de grafico de pastel

colores = ['#FFFF00', '#0000FF']  # Amarillo y Azul en formato hexadecimal

plt.figure(figsize=(16,7))
plt.title("Alojamientos SuperHost")
plt.pie(cantidades,labels = etiquetas,autopct='%1.1f%%',colors=colores)
plt.show()

# %%
## Para comparar la disponibilidad

media_disponibilidad=paises.availability_365.mean()

## Creacion de nueva columna

paises["Diferencia_Disponibilidad"]=paises["availability_365"]-media_disponibilidad

# %%
## Crear una variable para almacenar la media disponibile para cada zona

dif_disponibilidad=paises.groupby("host_location")[["Diferencia_Disponibilidad"]].mean()

##Filtrar las zonas con mayor disponibilidad comparando con el promedio
positivos=dif_disponibilidad[dif_disponibilidad.Diferencia_Disponibilidad<0]

##Filtrar las zonas con menos disponibilidad comparado con el promedio 
negativos=dif_disponibilidad[dif_disponibilidad.Diferencia_Disponibilidad<0]

##Creacion del grafico
plt.figure(figsize=(16,6))
plt.bar(positivos.index,positivos.Diferencia_Disponibilidad,color='#800000')
plt.bar(negativos.index,negativos.Diferencia_Disponibilidad,color='r')
plt.show()

# %%
##Calificaciones , buscar el promedio de los rating de comunicacion, limpieza y check in

#Agrupar los resultados segun la ubicacion y se calcula la media de las calificaciones

mejores_calificados=paises.groupby("host_location")[["review_scores_rating", "review_scores_communication","review_scores_cleanliness","review_scores_checkin"]].mean()
                                                    
## Ordenar de manera descendete segun el valor del review_scores_rating
                                                    
mejores_calificados.sort_values(by=["review_scores_rating"],ascending=False)
# Out:
#                             review_scores_rating  review_scores_communication  \
# host_location
# Sydney, Australia                            5.0                          5.0
# Abcoude, Netherlands                         5.0                          5.0
# Spierdijk, Netherlands                       5.0                          5.0
# Delft, Netherlands                           5.0                          5.0
# Sneek, Netherlands                           5.0                          5.0
# ...                                          ...                          ...
# South Holland, Netherlands                   NaN                          NaN
# Tel Aviv-Yafo, Israel                        NaN                          NaN
# Vienna, Austria                              NaN                          NaN
# Walbrzych, Poland                            NaN                          NaN
# Workum, Netherlands                          NaN                          NaN
#
# ...
