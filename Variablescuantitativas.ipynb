# %%
import pandas as pd
import numpy as np
import seaborn as sns
import dc_stat_think as dcst

# %%
## Exploracion Variables cuantatitvas 

datos = pd.read_csv(r"C:\Users\ViG\Desktop\DataSets\cars04.csv")
datos.head()
# Out:
#                           name  sports_car    suv  wagon  minivan  pickup  \
# 0           Chevrolet Aveo 4dr       False  False  False    False   False
# 1  Chevrolet Aveo LS 4dr hatch       False  False  False    False   False
# 2       Chevrolet Cavalier 2dr       False  False  False    False   False
# 3       Chevrolet Cavalier 4dr       False  False  False    False   False
# 4    Chevrolet Cavalier LS 2dr       False  False  False    False   False
#
#    all_wheel  rear_wheel   msrp  dealer_cost  eng_size  ncyl  horsepwr  \
# 0      False       False  11690        10965       1.6     4       103
# 1      False       False  12585        11802       1.6     4       103
# 2      False       False  14610        13697       2.2     4       140
# 3      False       False  14810        13884       2.2     4       140
# 4      False       False  16385        15357       2.2     4       140
#
#    city_mpg  hwy_mpg  weight  wheel_base  length  width
# ...

# %%
## Exploracion global variables numericas (resumen descriptivo) utilizando pandas
## round paraevitar muchos decimales 

datos.describe().round(1)
# Out:
#            msrp  dealer_cost  eng_size   ncyl  horsepwr  city_mpg  hwy_mpg  \
# count     428.0        428.0     428.0  428.0     428.0     414.0    414.0
# mean    32774.9      30014.7       3.2    5.8     215.9      20.1     26.9
# std     19431.7      17642.1       1.1    1.6      71.8       5.2      5.7
# min     10280.0       9875.0       1.3   -1.0      73.0      10.0     12.0
# 25%     20334.2      18866.0       2.4    4.0     165.0      17.0     24.0
# 50%     27635.0      25294.5       3.0    6.0     210.0      19.0     26.0
# 75%     39205.0      35710.2       3.9    6.0     255.0      21.0     29.0
# max    192465.0     173560.0       8.3   12.0     500.0      60.0     66.0
#
#        weight  wheel_base  length  width
# count   426.0       426.0   402.0  400.0
# mean   3577.2       108.2   185.1   71.3
# std     760.4         8.3    13.3    3.4
# min    1850.0        89.0   143.0   64.0
# 25%    3102.0       103.0   177.0   69.0
# 50%    3474.5       107.0   186.0   71.0
# ...

# %%
## Distribucion de cada una de las variables para encontrar incosistencias (utilizar histogramas)

datos.horsepwr.plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
datos.city_mpg.plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
datos.hwy_mpg.plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
## Funcion densidad para resolver enigmas o problemas o facilidad en el trabajo a traves de las probabilidades 

ax = datos.hwy_mpg.plot.hist(density=True)
datos.hwy_mpg.plot.density(ax=ax)
# Out:
# <Axes: ylabel='Density'>

# %%
## Grafico dispersion (Scatterplot) determinar que relacion existen entre las variables

## Relacion caballos de fuerza y consumo en ciudad

datos.plot.scatter(x='horsepwr', y='city_mpg')
# Out:
# <Axes: xlabel='horsepwr', ylabel='city_mpg'>

# %%
## Relacion caballos de fuerza y consumo en autopista

datos.plot.scatter(x='horsepwr', y='hwy_mpg')
# Out:
# <Axes: xlabel='horsepwr', ylabel='hwy_mpg'>

# %%
## Correlacion, esclaracer la relacion entre dos variables (indicador que permite ver que tan fuerte es la relacion) (PREGUNTA)

## Mapa de calor heatmap

##datos.corr().round(1)

# %%
## sns.heatmap(datos.corr().round(2)) REVISAR

# %%
datos.plot.scatter(x='horsepwr',y= 'dealer_cost')
# Out:
# <Axes: xlabel='horsepwr', ylabel='dealer_cost'>

# %%
## Analizar relaciones entre variables (Manipulacion y transformacion de datos) determinar filas por las especificaciones que se quiere
## grafico facetas de facetas

cyl = [4,6,8]
datos_filtro = datos[datos.ncyl.isin(cyl)]

sns.displot(
    datos_filtro, x="city_mpg", col="suv", row="ncyl",
    binwidth=3,height=3,facet_kws=dict(margin_titles=True)
)
# Out:
# C:\Users\ViG\anaconda3\lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.displot(
    datos_filtro, x="hwy_mpg", col="suv", row="ncyl",
    binwidth=3,height=3,facet_kws=dict(margin_titles=True)
)
# Out:
# C:\Users\ViG\anaconda3\lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
## Relacion variable cualitativa y cuantitava grafico de bigote o cajas # Boxplot

ax = datos_filtro.boxplot(by="sports_car",column="city_mpg")
ax.set_xlabel('Es carro deportivo')
ax.set_ylabel('')
# Out:
# Text(0, 0.5, '')

# %%
## Grafico con libreria seaborn

sns.boxplot(x="sports_car",y="city_mpg",data=datos_filtro)
# Out:
# <Axes: xlabel='sports_car', ylabel='city_mpg'>

# %%
## Funciones para determinar estadistica descriptiva

datos.city_mpg.mean()
# Out:
# 20.08937198067633

# %%
datos.city_mpg.median()
# Out:
# 19.0

# %%
datos.city_mpg.mode()
# Out:
# 0    18.0
# Name: city_mpg, dtype: float64

# %%
datos.city_mpg.max()
# Out:
# 60.0

# %%
## Promedio importado , se agrega cual porcentaje arriba y abajo se requiere 

from scipy.stats import trim_mean
trim_mean(datos['city_mpg'],0.1)
# Out:
# 19.747093023255815

# %%
## La varianza no se considera una medida 

datos.city_mpg.var()
# Out:
# 27.176012679697102

# %%
datos.city_mpg.std()
# Out:
# 5.213061737568154

# %%
## Calcular los cuartiles

datos.city_mpg.quantile([0.25,0.75])
# Out:
# 0.25    17.0
# 0.75    21.0
# Name: city_mpg, dtype: float64

# %%
## Calcular rango intercuantil ( valores atipicos)

Q1= datos.city_mpg.quantile(0.25)
Q3= datos.city_mpg.quantile(0.75)

## crear objeto para verificar las diferencias
IRQ = Q3-Q1
IRQ
# Out:
# 4.0

# %%
## Determinar los valores atipicos (extremos)
Q3 + 3*IRQ
# Out:
# 33.0
